# %%
import matplotlib.pyplot as plt
import numpy as np

def in_cm(num):
    return num*2.54

#simple plot
plt.plot([1,2,3,4],[2,4,7,16])

# %%
#setting up figure
fig = plt.figure() #emply figure with no axes
fig, ax = plt.subplots() #figure with one single axes
#axs = plt.subplots(3, 2) #figure with 3x2 grid of axes

# %%
x = np.linspace(0, 2, 100)
ax.plot(x, x, label="Linear")
ax.plot(x, x**2, label="Quadradtic")
ax.plot(x, x**3, label="Cubic")
ax.legend()
fig

# %%
#subplots return tuples with [0] figure, [#] axes#
fig2 = plt.subplots(3,3)
ax = fig2[1][2][1]
ax.plot(x, x, label="Linear")
ax.plot(x, x**2, label="Quadradtic")
ax.plot(x, x**3, label="Cubic")
fig2
# Out:
# (<Figure size 432x288 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3a7aa60400>,
# ...
#        dtype=object))

# %%
#scatter

# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

fig3 = plt.subplots()
fig3[0].set_size_inches(18.5, 10.5)
fig3[1].scatter(x, y, s=x*100, c=colors, alpha=0.5)
